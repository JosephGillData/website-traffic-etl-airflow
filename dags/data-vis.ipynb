# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/traffic_data.csv')

# %%
df.head()
# Out:
#       bf_date   bf_time     id               ip      gbps
# 0  2021-08-13  00:00:00  24659  184.184.120.243  2.671486
# 1  2021-08-13  00:00:00  24659     28.250.103.2  3.166408
# 2  2021-08-13  00:00:00  13181  210.108.127.238  4.097512
# 3  2021-08-13  00:00:00  24659  196.178.105.179  2.510341
# 4  2021-08-13  00:00:00  13181     68.241.16.87  4.170406

# %%
np.shape(df)
# Out:
# (61150, 5)

# %%
df['bf_date'] = pd.to_datetime(df['bf_date'])
df['bf_time'] = pd.to_datetime(df['bf_time'], format='%H:%M:%S').dt.time

# %%
print(df['bf_date'].min())
print(df['bf_date'].max())
# Out:
# 2021-08-13 00:00:00
# 2021-08-14 00:00:00
